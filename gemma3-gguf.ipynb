# %%
# !pip install -U llama-cpp-python
# Out:
# Requirement already satisfied: llama-cpp-python in /usr/local/lib/python3.11/dist-packages (0.3.8)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (2.0.2)
# Requirement already satisfied: diskcache>=5.6.1 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in /usr/local/lib/python3.11/dist-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.2)

# %%
system_prompt = """
You are a JSON-only response system. Follow these rules absolutely:
1. ONLY output valid, parseable JSON
2. NEVER include text before or after the JSON
3. NEVER include markdown code blocks or formatting
4. NEVER include explanations
5. NEVER extract dates
6. If you can't fulfill a request, return {"error": "error message"}
7. Output should always be a single JSON object

For address requests, use this format:
{
    "address": {
        "license": "B1231241",
        "Address": "X City",
        "Sex": "Male",
        "Weight": "X",
        "Height": "X"
    }
}
"""

# %%
test_instruction = '''extract NER:
        California
        DRIVER LICENSe
        dl 11234568
        CLASS C
        EXP 08/31/2014
        END NONE
        LNCARDHOLDER FNIMA
        2570 24TH STREET ANYTOWN, CA 95818
        doB 08/31/1977 RSTR NONE
        08311977
        VETERAN
        Cordhslde
        SEX F HGT 5'-05"
        HAIR BRN WGT 125 lb
        EYES BRN
        DD 00/00/0000NNNAN/ANFD/YY
        ISS 08/31/2009
'''

# %% [markdown]
# # gemma-3

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-1b-it-GGUF",
	filename="gemma-3-1b-it-BF16.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# ```json
# {
#     "address": {
#         "license": "B1231241",
#         "Address": "X City",
#         "Sex": "Male",
#         "Weight": "X",
#         "Height": "X"
#     }
# }
# ```
# llama_perf_context_print:        load time =   29822.61 ms
# llama_perf_context_print: prompt eval time =   29821.83 ms /   343 tokens (   86.94 ms per token,    11.50 tokens per second)
# llama_perf_context_print:        eval time =   21773.81 ms /    65 runs   (  334.98 ms per token,     2.99 tokens per second)
# llama_perf_context_print:       total time =   51944.66 ms /   408 tokens
# Time taken: 51.9596 seconds

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-1b-it-GGUF",
	filename="gemma-3-1b-it-Q8_0.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# ```json
# {
#     "address": {
#         "license": "B1231241",
#         "Address": "X City",
#         "Sex": "Male",
#         "Weight": "X",
#         "Height": "X"
#     }
# }
# ```
# llama_perf_context_print:        load time =   23230.23 ms
# llama_perf_context_print: prompt eval time =   23229.41 ms /   343 tokens (   67.72 ms per token,    14.77 tokens per second)
# llama_perf_context_print:        eval time =   12591.26 ms /    65 runs   (  193.71 ms per token,     5.16 tokens per second)
# llama_perf_context_print:       total time =   36162.23 ms /   408 tokens
# Time taken: 36.1701 seconds

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-1b-it-GGUF",
	filename="gemma-3-1b-it-Q6_K.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# ```json
# {
#     "address": {
#         "license": "B1231241",
#         "Address": "X City",
#         "Sex": "Male",
#         "Weight": "X",
#         "Height": "X"
#     }
# }
# ```
# llama_perf_context_print:        load time =   27860.15 ms
# llama_perf_context_print: prompt eval time =   27859.38 ms /   343 tokens (   81.22 ms per token,    12.31 tokens per second)
# llama_perf_context_print:        eval time =   16862.67 ms /    65 runs   (  259.43 ms per token,     3.85 tokens per second)
# llama_perf_context_print:       total time =   45150.96 ms /   408 tokens
# Time taken: 45.1780 seconds

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-1b-it-GGUF",
	filename="gemma-3-1b-it-Q4_K_M.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# ```json
# {
#     "address": {
#         "license": "B1231241",
#         "Address": "X City",
#         "Sex": "Male",
#         "Weight": "X",
#         "Height": "X"
#     }
# }
# ```
# llama_perf_context_print:        load time =   30742.28 ms
# llama_perf_context_print: prompt eval time =   30741.55 ms /   343 tokens (   89.63 ms per token,    11.16 tokens per second)
# llama_perf_context_print:        eval time =   17221.03 ms /    65 runs   (  264.94 ms per token,     3.77 tokens per second)
# llama_perf_context_print:       total time =   48437.38 ms /   408 tokens
# Time taken: 48.4524 seconds

# %% [markdown]
# 4B

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-4b-it-GGUF",
	filename="gemma-3-4b-it-BF16.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# ```json
# {
#     "entities": [
#         {"entity": "California", "type": "GPE"},
#         {"entity": "dl 11234568", "type": "LICENSE"},
#         {"entity": "CLASS C", "type": "LICENSE_CLASS"},
#         {"entity": "08/31/2014", "type": "EXPIRATION_DATE"},
#         {"entity": "2570 24TH STREET ANYTOWN, CA 95818", "type": "ADDRESS"},
#         {"entity": "08/31/1977", "type": "DATE_OF_BIRTH"},
#         {"entity": "125 lb", "type": "WEIGHT
# llama_perf_context_print:        load time =   72789.37 ms
# llama_perf_context_print: prompt eval time =   72788.43 ms /   343 tokens (  212.21 ms per token,     4.71 tokens per second)
# llama_perf_context_print:        eval time =  169989.08 ms /   168 runs   ( 1011.84 ms per token,     0.99 tokens per second)
# llama_perf_context_print:       total time =  243499.23 ms /   511 tokens
# Time taken: 243.5084 seconds

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-4b-it-GGUF",
	filename="gemma-3-4b-it-Q8_0.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
#
# ```json
# {
#     "ner": [
#         "California",
#         "DRIVER LICENSe",
#         "dl 11234568",
#         "CLASS C",
#         "EXP 08/31/2014",
#         "END NONE",
#         "LNCARDHOLDER FNIMA",
#         "2570 24TH STREET ANYTOWN, CA 95818",
#         "doB 08/31/1977 RSTR NONE",
#         "08311977",
#         "VETERAN",
#         "Cordhslde",
#         "SEX F HGT 5'-05\"",
# llama_perf_context_print:        load time =   69307.21 ms
# llama_perf_context_print: prompt eval time =   69306.40 ms /   350 tokens (  198.02 ms per token,     5.05 tokens per second)
# llama_perf_context_print:        eval time =   99115.43 ms /   161 runs   (  615.62 ms per token,     1.62 tokens per second)
# llama_perf_context_print:       total time =  169125.87 ms /   511 tokens
# Time taken: 169.1353 seconds

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-4b-it-GGUF",
	filename="gemma-3-4b-it-IQ4_XS.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# ```json
# {
#     "entities": [
#         {"entity": "California", "type": "LOCATION"},
#         {"entity": "dl 11234568", "type": "LICENSE"},
#         {"entity": "CLASS C", "type": "LICENSE_CLASS"},
#         {"entity": "08/31/2014", "type": "EXPIRATION_DATE"},
#         {"entity": "2570 24TH STREET ANYTOWN, CA 95818", "type": "ADDRESS"},
#         {"entity": "08/31/1977", "type": "DATE_OF_BIRTH"},
#         {"entity": "VETERAN", "type": "STATUS"}
# llama_perf_context_print:        load time =  126010.86 ms
# llama_perf_context_print: prompt eval time =  126010.05 ms /   343 tokens (  367.38 ms per token,     2.72 tokens per second)
# llama_perf_context_print:        eval time =   76481.90 ms /   168 runs   (  455.25 ms per token,     2.20 tokens per second)
# llama_perf_context_print:       total time =  203186.75 ms /   511 tokens
# Time taken: 203.2090 seconds

# %%
from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="unsloth/gemma-3-12b-it-GGUF",
	filename="gemma-3-12b-it-UD-IQ1_S.gguf",
)

# %%
import time  # Import the time module

# --- Assuming generate_text, model, tokenizer, test_instruction are defined elsewhere ---

print("Starting text generation...") # Optional: Indicate start

start_time = time.perf_counter()  # Get the time just before the call

####################



for chunk in llm.create_chat_completion(
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": test_instruction
        }
    ],
    stream=True
):
    print(chunk['choices'][0]['delta'].get('content', ''), end='', flush=True)

#########################################

end_time = time.perf_counter()    # Get the time just after the call

elapsed_time = end_time - start_time # Calculate the difference

# Print the elapsed time
print(f"\nTime taken: {elapsed_time:.4f} seconds")
# Out:
# Starting text generation...
# {"extract": "California"}
# llama_perf_context_print:        load time =  579636.46 ms
# llama_perf_context_print: prompt eval time =  579635.72 ms /   343 tokens ( 1689.90 ms per token,     0.59 tokens per second)
# llama_perf_context_print:        eval time =   11318.07 ms /     6 runs   ( 1886.34 ms per token,     0.53 tokens per second)
# llama_perf_context_print:       total time =  590999.83 ms /   349 tokens
# Time taken: 591.0168 seconds
